# %% [markdown]
# <a href="https://colab.research.google.com/github/dinithprimal/DeepLearning_Tutorials/blob/main/Ex03_Cost_Lost_Functions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

y_predicted = np.array([1, 1, 0, 0, 1])
y_true = np.array([0.30, 0.7, 1, 0, 0.5])

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def mae(y_true, y_predicted):
  total_error = 0
  for yt, yp in zip(y_true, y_predicted):
    total_error += abs(yt - yp)
  print("Total Error:",total_error)

  mae = total_error/len(y_true)
  print("MAE:",mae)

  return mae

# %%
mae(y_true, y_predicted)
# Out:
# Total Error: 2.5
# MAE: 0.5
# 0.5

# %%
np.mean(np.abs(y_predicted - y_true))
# Out:
# 0.5

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
np.log([0])
# Out:
# <ipython-input-8-faee82fd9f21>:1: RuntimeWarning: divide by zero encountered in log
#   np.log([0])
# array([-inf])

# %%
np.log([0.000000000000000001])
# Out:
# array([-41.44653167])

# %%
epsilon = 1e-15

# %%
y_predicted_new = [max(i, epsilon) for i in y_predicted]
y_predicted_new
# Out:
# [1, 1, 1e-15, 1e-15, 1]

# %%
y_predicted_new = [min(i, 1-epsilon) for i in y_predicted_new]
y_predicted_new
# Out:
# [0.999999999999999, 0.999999999999999, 1e-15, 1e-15, 0.999999999999999]

# %%
y_predicted_new = np.array(y_predicted_new)
np.log(y_predicted_new)
# Out:
# array([-9.99200722e-16, -9.99200722e-16, -3.45387764e+01, -3.45387764e+01,
#        -9.99200722e-16])

# %%
-np.mean(y_true * np.log(y_predicted_new) + (1 - y_true) * np.log(1 - y_predicted_new))
# Out:
# 17.2696280766844

# %%
def log_loss(y_true, y_predicted):
  epsilon = 1e-15
  y_predicted_new = [max(i, epsilon) for i in y_predicted]
  y_predicted_new = [min(i, 1-epsilon) for i in y_predicted_new]
  y_predicted_new = np.array(y_predicted_new)
  return -np.mean(y_true * np.log(y_predicted_new) + (1 - y_true) * np.log(1 - y_predicted_new))

# %%
log_loss(y_true, y_predicted)
# Out:
# 17.2696280766844

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def mse(y_true, y_predicted):
  total_error = 0
  for yt, yp in zip(y_true, y_predicted):
    total_error += (yt - yp) ** 2
  print("Total Error:",total_error)

  mae = total_error/len(y_true)
  print("MAE:",mae)

  return mae

# %%
mse(y_true, y_predicted)
# Out:
# Total Error: 1.83
# MAE: 0.366
# 0.366

# %%
np.mean(np.square(y_predicted - y_true))
# Out:
# 0.366
